# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_45183.csv")
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2015        2016        2017        2018        2019        2020  \
# ...

# %%
df.shape
# Out:
# (266, 69)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# Unnamed: 68       float64
# Length: 69, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.695500e+08  3.740958e+08  3.808121e+08  3.895098e+08  3.982497e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum().any()
# Out:
# True

# %%
df=df.fillna(method='ffill')
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df.isna().sum().any()
# Out:
# True

# %%
df.isna().sum().any()
# Out:
# True

# %%
df['Country Name'].unique()
# Out:
# array([], dtype=object)

# %%
df['Country Code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA',
# ...

# %%
df['Indicator Name'].unique()
# Out:
# array([], dtype=object)

# %%
df['Indicator Code'].unique()
# Out:
# array(['SP.POP.TOTL'], dtype=object)

# %%
df.drop(['Indicator Name','Indicator Code','Country Code'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
cols=['1960', '1961', '1962', '1963', '1964', '1965', '1966',
       '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
       '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
       '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
       '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
       '2021', '2022']

# %%
for i in cols:
    fig=plt.figure(figsize=(5,5))
    plt.hist(df[i],color='#B22222',bins=10)
    plt.xlabel(i)
    plt.show()

# %%
years=df.columns[5:]
total_values=df[years].sum()
plt.figure(figsize=(30,30))
plt.barh(years,total_values,color='#191970')
plt.xlabel('Total Values')
plt.ylabel('Year',size=20)
plt.title('Total Values per Year',size=20)
plt.show()

# %%
country_by_1960=df.sort_values(by='1960').head(20)
country_by_1960
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 225  Sint Maarten (Dutch part)          SXM  Population, total    SP.POP.TOTL
# 147   St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 179                      Nauru          NRU  Population, total    SP.POP.TOTL
# 245                     Tuvalu          TUV  Population, total    SP.POP.TOTL
# 228   Turks and Caicos Islands          TCA  Population, total    SP.POP.TOTL
# 255     British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 52              Cayman Islands          CYM  Population, total    SP.POP.TOTL
# 164   Northern Mariana Islands          MNP  Population, total    SP.POP.TOTL
# 6                      Andorra          AND  Population, total    SP.POP.TOTL
# 188                      Palau          PLW  Population, total    SP.POP.TOTL
# 155           Marshall Islands          MHL  Population, total    SP.POP.TOTL
# ...

# %%
print(f"Processing country: {country_name}")
print("Data index (years):", data_values.index)
print("Data values:", data_values.values)
print("Data index types:", data_values.index.dtype)
print("Data values types:", data_values.values.dtype)
# Out:
# Processing country: Sint Maarten (Dutch part)
# Data index (years): Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023',
#        'Unnamed: 68'],
#       dtype='object')
# Data values: ['SXM' 'Population, total' 'SP.POP.TOTL' 2646.0 2888.0 3171.0 3481.0
#  3811.0 4161.0 4531.0 4930.0 5354.0 5795.0 6260.0 6736.0 7226.0 7750.0
#  8312.0 8906.0 9523.0 10172.0 10850.0 11542.0 12243.0 13134.0 14418.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


country_by_1960_t = country_by_1960.set_index('Country Name')


non_year_columns = ['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 68']
country_by_1960_t = country_by_1960_t.drop(columns=non_year_columns)


country_by_1960_t.columns = country_by_1960_t.columns.astype(str)
country_by_1960_t = country_by_1960_t.apply(pd.to_numeric, errors='coerce')


for country_name, data_values in country_by_1960_t.iterrows():
    
    print(f"Processing country: {country_name}")
    print("Data index (years):", data_values.index)
    print("Data values:", data_values.values)
    print("Data index types:", data_values.index.dtype)
    print("Data values types:", data_values.values.dtype)

    
    fig = plt.figure(figsize=(10, 5))
    
    
    sns.barplot(x=data_values.index, y=data_values.values)
    

    plt.xlabel('Years')
    plt.ylabel('Data Values')
    plt.title(f"{country_name} - Data Values from 1960 to 2022")
    
    
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Processing country: Sint Maarten (Dutch part)
# Data index (years): Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')
# Data values: [ 2646.  2888.  3171.  3481.  3811.  4161.  4531.  4930.  5354.  5795.
#   6260.  6736.  7226.  7750.  8312.  8906.  9523. 10172. 10850. 11542.
#  12243. 13134. 14418. 15927. 17474. 19064. 20703. 22395. 24139. 25952.
#  27845. 29820. 31345. 31823. 31735. 31596. 31410. 31195. 31240. 31084.
# ...

# %%
country_by_2022=df.sort_values(by='2022').head(20)
country_by_2022
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 245                     Tuvalu          TUV  Population, total    SP.POP.TOTL
# 179                      Nauru          NRU  Population, total    SP.POP.TOTL
# 188                      Palau          PLW  Population, total    SP.POP.TOTL
# 255     British Virgin Islands          VGB  Population, total    SP.POP.TOTL
# 147   St. Martin (French part)          MAF  Population, total    SP.POP.TOTL
# 84                   Gibraltar          GIB  Population, total    SP.POP.TOTL
# 212                 San Marino          SMR  Population, total    SP.POP.TOTL
# 149                     Monaco          MCO  Population, total    SP.POP.TOTL
# 137              Liechtenstein          LIE  Population, total    SP.POP.TOTL
# 155           Marshall Islands          MHL  Population, total    SP.POP.TOTL
# 225  Sint Maarten (Dutch part)          SXM  Population, total    SP.POP.TOTL
# ...

# %%
country_by_2022_t = country_by_2022.set_index('Country Name')


non_year_columns = ['Country Code', 'Indicator Name', 'Indicator Code', 'Unnamed: 68']
country_by_2022_t = country_by_2022_t.drop(columns=non_year_columns)


country_by_2022_t.columns = country_by_2022_t.columns.astype(str)
country_by_2022_t = country_by_2022_t.apply(pd.to_numeric, errors='coerce')


for country_name, data_values in country_by_2022_t.iterrows():
    
    print(f"Processing country: {country_name}")
    print("Data index (years):", data_values.index)
    print("Data values:", data_values.values)
    print("Data index types:", data_values.index.dtype)
    print("Data values types:", data_values.values.dtype)

    
    fig = plt.figure(figsize=(10, 5))
    
    
    sns.barplot(x=data_values.index, y=data_values.values)
    

    plt.xlabel('Years')
    plt.ylabel('Data Values')
    plt.title(f"{country_name} - Data Values from 1960 to 2022")
    
    
    plt.xticks(rotation=90)
    plt.show()
# Out:
# Processing country: Tuvalu
# Data index (years): Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')
# Data values: [ 5404.  5436.  5471.  5503.  5525.  5548.  5591.  5657.  5729.  5779.
#   5814.  5854.  5891.  5934.  6100.  6381.  6677.  6984.  7297.  7552.
#   7731.  7874.  7993.  8099.  8197.  8329.  8496.  8665.  8844.  9017.
#   9182.  9354.  9466.  9517.  9559.  9585.  9611.  9630.  9634.  9640.
# ...
